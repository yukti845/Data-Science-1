# %% [markdown]
# # Plotting From Pandas DataFrames

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/a1s1cmd/opt/anaconda3/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/a1s1cmd/opt/anaconda3/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/a1s1cmd/opt/anaconda3/lib/python3.7/site-packages (from pandas) (2019.3)
# Requirement already satisfied: numpy>=1.13.3 in /Users/a1s1cmd/opt/anaconda3/lib/python3.7/site-packages (from pandas) (1.16.0)
# Requirement already satisfied: six>=1.5 in /Users/a1s1cmd/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Make a dataframes
car_sales = pd.read_csv("car_sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range("1/1/2020", periods=1000))
ts = ts.cumsum()
ts.plot()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sale Date   Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sale Date   Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
# Remove last two zeros
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors Price Sale Date   Total Sales
# 0  Toyota  White         150043      4    40 2020-01-01         4000
# 1   Honda    Red          87899      4    50 2020-01-02         9000
# 2  Toyota   Blue          32549      3    70 2020-01-03        16000
# 3     BMW  Black          11179      5   220 2020-01-04        38000
# 4  Nissan  White         213095      4    35 2020-01-05        41500
# 5  Toyota  Green          99213      4    45 2020-01-06        46000
# 6   Honda   Blue          45698      4    75 2020-01-07        53500
# 7   Honda   Blue          54738      4    70 2020-01-08        60500
# 8  Toyota  White          60000      4    62 2020-01-09        66750
# 9  Nissan  White          31600      4    97 2020-01-10        76450

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2020", periods = len(car_sales))

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors Price Sale Date   Total Sales
# 0  Toyota  White         150043      4    40 2020-01-01         4000
# 1   Honda    Red          87899      4    50 2020-01-02         9000
# 2  Toyota   Blue          32549      3    70 2020-01-03        16000
# 3     BMW  Black          11179      5   220 2020-01-04        38000
# 4  Nissan  White         213095      4    35 2020-01-05        41500
# 5  Toyota  Green          99213      4    45 2020-01-06        46000
# 6   Honda   Blue          45698      4    75 2020-01-07        53500
# 7   Honda   Blue          54738      4    70 2020-01-08        60500
# 8  Toyota  White          60000      4    62 2020-01-09        66750
# 9  Nissan  White          31600      4    97 2020-01-10        76450

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors Price Sale Date   Total Sales
# 0  Toyota  White         150043      4    40 2020-01-01           40
# 1   Honda    Red          87899      4    50 2020-01-02           90
# 2  Toyota   Blue          32549      3    70 2020-01-03          160
# 3     BMW  Black          11179      5   220 2020-01-04          380
# 4  Nissan  White         213095      4    35 2020-01-05          415
# 5  Toyota  Green          99213      4    45 2020-01-06          460
# 6   Honda   Blue          45698      4    75 2020-01-07          535
# 7   Honda   Blue          54738      4    70 2020-01-08          605
# 8  Toyota  White          60000      4    62 2020-01-09          667
# 9  Nissan  White          31600      4    97 2020-01-10          764

# %%
# Let's plot the total sales

car_sales.plot(x="Sale Date", y="Total Sales");

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")

# %%
# Reassing price colum to int
car_sales["Price"] = car_sales["Price"].astype(int)

# Plot scatter plot with price column as numeric
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
# How about a bar graph ?

x = np.random.rand(10, 4)
x

# Turn it into a dataframe

df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.336044  0.745641  0.742396  0.177376
# 1  0.054041  0.362356  0.489171  0.741229
# 2  0.709067  0.076328  0.525016  0.996768
# 3  0.026771  0.654807  0.730373  0.143795
# 4  0.369470  0.355246  0.012578  0.121183
# 5  0.850917  0.895095  0.509188  0.430021
# 6  0.972053  0.643053  0.653232  0.664935
# 7  0.291515  0.487689  0.973161  0.691069
# 8  0.118712  0.642325  0.575356  0.797671
# 9  0.626076  0.739714  0.072192  0.638143

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sale Date   Total Sales  \
# 0  Toyota  White         150043      4     40 2020-01-01           40
# 1   Honda    Red          87899      4     50 2020-01-02           90
# 2  Toyota   Blue          32549      3     70 2020-01-03          160
# 3     BMW  Black          11179      5    220 2020-01-04          380
# 4  Nissan  White         213095      4     35 2020-01-05          415
# 5  Toyota  Green          99213      4     45 2020-01-06          460
# 6   Honda   Blue          45698      4     75 2020-01-07          535
# 7   Honda   Blue          54738      4     70 2020-01-08          605
# 8  Toyota  White          60000      4     62 2020-01-09          667
# 9  Nissan  White          31600      4     97 2020-01-10          764
#
#    Sale Date
# 0 2020-01-01
# 1 2020-01-02
# 2 2020-01-03
# 3 2020-01-04
# 4 2020-01-05
# 5 2020-01-06
# 6 2020-01-07
# 7 2020-01-08
# 8 2020-01-09
# 9 2020-01-10

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot.hist(bins=20);
